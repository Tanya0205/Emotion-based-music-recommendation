# %%
import os
import numpy as np
import cv2

# %%
import mediapipe as mp 
from keras.models import load_model

# %%
model  = load_model("my_model.keras")
label = np.load("labels.npy")

# %%
holistic = mp.solutions.holistic
hands = mp.solutions.hands
holis = holistic.Holistic()
drawing = mp.solutions.drawing_utils

# %%
cap = cv2.VideoCapture(0)



while True:
	lst = []

	_, frm = cap.read()

	frm = cv2.flip(frm, 1)

	res = holis.process(cv2.cvtColor(frm, cv2.COLOR_BGR2RGB))


	if res.face_landmarks:
		for i in res.face_landmarks.landmark:
			lst.append(i.x - res.face_landmarks.landmark[1].x)
			lst.append(i.y - res.face_landmarks.landmark[1].y)

		if res.left_hand_landmarks:
			for i in res.left_hand_landmarks.landmark:
				lst.append(i.x - res.left_hand_landmarks.landmark[8].x)
				lst.append(i.y - res.left_hand_landmarks.landmark[8].y)
		else:
			for i in range(42):
				lst.append(0.0)

		if res.right_hand_landmarks:
			for i in res.right_hand_landmarks.landmark:
				lst.append(i.x - res.right_hand_landmarks.landmark[8].x)
				lst.append(i.y - res.right_hand_landmarks.landmark[8].y)
		else:
			for i in range(42):
				lst.append(0.0)

		lst = np.array(lst).reshape(1,-1)

		pred = label[np.argmax(model.predict(lst))]

		print(pred)
		cv2.putText(frm, pred, (50,50),cv2.FONT_ITALIC, 1, (255,0,0),2)

		
	drawing.draw_landmarks(frm, res.face_landmarks, holistic.FACEMESH_CONTOURS)
	drawing.draw_landmarks(frm, res.left_hand_landmarks, hands.HAND_CONNECTIONS)
	drawing.draw_landmarks(frm, res.right_hand_landmarks, hands.HAND_CONNECTIONS)

	cv2.imshow("window", frm)

	if cv2.waitKey(1) == 27:
		cv2.destroyAllWindows()
		cap.release()
		break
# Out:
# C:\Users\Tanya\anaconda3\Lib\site-packages\google\protobuf\symbol_database.py:55: UserWarning: SymbolDatabase.GetPrototype() is deprecated. Please use message_factory.GetMessageClass() instead. SymbolDatabase.GetPrototype() will be removed soon.
#   warnings.warn('SymbolDatabase.GetPrototype() is deprecated. Please '
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 226ms/step
# cheerful
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# cheerful
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# cheerful
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# cheerful
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# cheerful
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# cheerful
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# cheerful
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# cheerful
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# dancing
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# cheerful
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# cheerful
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# sad
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# sad
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# sad
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# sad
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# cheerful
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# cheerful
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# cheerful
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# cheerful
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# cheerful
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# cheerful
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# cheerful
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# cheerful
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# cheerful
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# cheerful
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# cheerful
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# cheerful
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# cheerful
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# cheerful
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# cheerful
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# cheerful
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# dancing
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# dancing
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# dancing
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# dancing
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# dancing
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# dancing
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# dancing
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# dancing
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# dancing
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# dancing
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# dancing
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# dancing
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# loving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# loving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# loving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# loving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# loving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# loving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# loving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# loving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# sad
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# sad
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# sad
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# sad
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# sad
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# sad
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# sad
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# sad
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# sad
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# sad
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# sad
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# sad
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# sad
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# sad
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# sad
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# sad
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# sad
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# sad
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# sad
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# sad
